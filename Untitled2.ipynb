# %%
import numpy as np
data=np.array([
    [20,30000,1],
    [25,40000,0],
    [30,50000,1],
    [35,70000,1],
    [40,90000,0]
])
age=data[:,0]
print("1.age column:",age)
# Out:
# 1.age column: [20 25 30 35 40]

# %%
salary=data[:,1]
print(salary)
# Out:
# [30000 40000 50000 70000 90000]

# %%
avg_salary=np.mean(data[:,1])
print(avg_salary)
# Out:
# 56000.0

# %%
high_salary = data[data[:,1] > 50000]
print(high_salary)
# Out:
# [[   35 70000     1]
#  [   40 90000     0]]

# %%
count_ones=np.sum(data[:,2]==1)
print(count_ones)
# Out:
# 3
