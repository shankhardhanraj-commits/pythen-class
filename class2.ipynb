# %%
a=10
b=7
print("addition is",a+b)
# Out:
# addition is 17

# %%
fname="dhanraj"
lname="shankhar"

# %%
fullname=fname+" "+lname
print(fullname)
# Out:
# dhanraj shankhar

# %%
text="machine learning"
print(text.upper())
# Out:
# MACHINE LEARNING

# %%
print(text.lower())
# Out:
# machine learning

# %%
print(len(text))
# Out:
# 16

# %%
name=input("enter your name:")
print("hello,nameste",name)
# Out:
# enter your name: dhanraj shankhar
# hello,nameste dhanraj shankhar

# %%
age=int(input("enter your age"))
print("your age is",age)
# Out:
# enter your age 22
# your age is 22

# %%
print("next year you will be:",age+1)
# Out:
# next year you will be: 23

# %%
marks=[60,75,80,90,55]

# %%
print(marks)
# Out:
# [60, 75, 80, 90, 55]

# %%
print(marks[0])
# Out:
# 60

# %%
print(marks[2])
# Out:
# 80

# %%
secondyear=["dev","dhan","bishal","sus","anant"]

# %%
print(secondyear[4])
# Out:
# anant

# %%
print(len(secondyear))
# Out:
# 5

# %%
marks=[60,75,80,90,55]

# %%
print("max",max(marks))
# Out:
# max 90

# %%
print("min",min(marks))
# Out:
# min 55

# %%
print("sum",sum(marks))
# Out:
# sum 360

# %%
marks=70
if marks >=60:
    print("pss")
else:
    print("fail")
# Out:
# pss

# %%
age=15
if age >=18:
    print("you can vote")
else:
    print("you can not vote")
# Out:
# you can not vote

# %%
marks=87
if marks >=90:
    print("grade a")
elif marks >=80:
    print("grade b")
elif marks >=70:
    print("grade c")
elif marks >=60:
    print("grade d")
else:
    print("fail")
# Out:
# grade b
