# %%
print("hello world")
# Out:
# hello world

# %%
print("welcome to python") #this
# Out:
# welcome to python

# %%
name=("dhanraj")
print("my name is",name)
# Out:
# my name is dhanraj

# %%
citizenship="nepali"
age=22
votercard="yes"

if citizenship="nepali"
elif age >=18

# %%
citizenship=input("are you a nepali citizen:")
if citizenship=="no":
   print("you canot vote becouse you are not a nepali citizen.")
    
elif citizenship == "yes":
    age=int(input("enter your age:"))
    if age < 18:
        print("you canot vote becouse you are under 18 years old.")
    else:
        votercard =input("do you have a voter card:")
        if votercard=="yes":
            print("you can eligible to vote in nepali.")
        else:
            print("you cannot vote because you do not have a voter card.")
else:
    print("please only input yes or no")
# Out:
# are you a nepali citizen: yes
# enter your age: 22
# do you have a voter card: yes
# you can eligible to vote in nepali.

# %%
marks=int(input("enter your marks:"))
if marks >=90:
    print("grade a")
elif marks >=80:
    print("grade b")
elif marks >=70:
    print("grade c")
elif marks >=60:
    print("grade d")
else:
    print("fail")
# Out:
# enter your marks: 90
# grade a
